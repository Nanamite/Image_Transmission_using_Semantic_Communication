# %%
import pandas as pd
import numpy as np

# %%
# Load the data
data = pd.read_csv(r'ber_object_detection.csv')
data
# Out:
#       background   person   image    K       BER   SNR
# 0              1        1       0    1  0.055919     1
# 1              1        1       0    1  0.038129     2
# 2              1        1       0    1  0.022466     3
# 3              1        1       0    1  0.012590     4
# 4              1        1       0    1  0.005428     5
# ...          ...      ...     ...  ...       ...   ...
# 3019           3        3       5  128  0.002975     3
# 3020           3        3       5  128  0.000000     4
# 3021           3        3       5  128  0.000000     5
# 3022           3        3       5  128  0.000000     6
# 3023           3        3       5  128  0.000000     7
#
# [3024 rows x 6 columns]

# %%
data.columns = data.columns.str.strip()

# %%
# For each SNR value, calculate the average BER for each K value
data_grouped = data.groupby(['SNR', 'K']).mean()
data_grouped = data_grouped.reset_index()

# %%
# Plot BER vs SNR for each K value
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[data_grouped['K'] == K]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.grid()
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR for different K values using object detection')
plt.legend()
plt.show()

# %%
# Plot BER vs SNR for each K value for background == 1
data_grouped = data.groupby(['SNR', 'K', 'background']).mean()
data_grouped = data_grouped.reset_index()

plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[(data_grouped['K'] == K) & (data_grouped['background'] == 1)]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR using object detection: background = 1')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[(data_grouped['K'] == K) & (data_grouped['background'] == 2)]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR using object detection: background = 2')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[(data_grouped['K'] == K) & (data_grouped['background'] == 3)]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR using object detection: background = 3')
plt.legend()
plt.grid()
plt.show()

# %%
data_grouped = data.groupby(['SNR', 'K', 'person']).mean()
data_grouped = data_grouped.reset_index()
data_grouped
# Out:
#      SNR    K  person  background  image       BER
# 0      1    1       1         2.0    2.5  0.056081
# 1      1    1       2         2.0    2.5  0.056179
# 2      1    1       3         2.0    2.5  0.056824
# 3      1    2       1         2.0    2.5  0.081792
# 4      1    2       2         2.0    2.5  0.080808
# ..   ...  ...     ...         ...    ...       ...
# 163    7   64       2         2.0    2.5  0.000000
# 164    7   64       3         2.0    2.5  0.000000
# 165    7  128       1         2.0    2.5  0.000000
# 166    7  128       2         2.0    2.5  0.000000
# 167    7  128       3         2.0    2.5  0.000000
#
# [168 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[(data_grouped['K'] == K) & (data_grouped['person'] == 1)]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR using object detection: 1 person')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[(data_grouped['K'] == K) & (data_grouped['person'] == 2)]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR using object detection: 2 persons')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy()
for K in data_grouped['K'].unique():
    data_K = data_grouped[(data_grouped['K'] == K) & (data_grouped['person'] == 3)]
    # Drop K = 128
    if K == 128:
        continue
    plt.plot(data_K['SNR'], data_K['BER'], label=f'K = {K}')
    
plt.xlabel('SNR (dB)')
plt.ylabel('BER')
plt.title('BER vs SNR using object detection: 3 persons')
plt.legend()
plt.grid()
plt.show()
